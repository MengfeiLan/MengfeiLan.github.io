# %%
import pandas as pd
import numpy as np

import bqplot
import numpy as np
import ipywidgets

# %%
dataset = pd.read_csv("building_inventory.csv")

# %%
dataset
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
data = pd.pivot_table(dataset, values='Square Footage', index=['Congress Dist'],columns=['Agency Name'], aggfunc=np.sum)

# %%
data
# Out:
# Agency Name    Appellate Court / Fifth District  \
# Congress Dist
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                      15124.0
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...

# %% [markdown]
# ### Fill 0 to NaNs

# %%
data = data.fillna(0)

# %%
mySelectedLabel = ipywidgets.Label()

# %%
linedata = dataset[dataset["Year Acquired"] > 1600].groupby("Year Acquired")["Square Footage"].sum()
xl = linedata.index  # Year Acquired
yl = linedata.values # Total Square Footage acquired that year
x_scl = bqplot.LinearScale()
y_scl = bqplot.LinearScale()


x_axl = bqplot.Axis(scale = x_scl, 
                    label = 'Year')
y_axl = bqplot.Axis(scale = y_scl, 
                    orientation = 'vertical', 
                    label='Total Square Footage Acquired')

lines = bqplot.Lines(x = xl, y = yl, scales = {'x': x_scl, 'y': y_scl})

figl = bqplot.Figure(marks = [lines], axes = [x_axl, y_axl])

# %%
def on_selected(change):
    if len(change['owner'].selected) == 1:
        grid = change['owner'].selected[0]
        colname = data.columns[grid[1]]
        mySelectedLabel.value = 'Data Value = ' + str(grid) # set our label
        new_df = dataset.loc[(dataset["Agency Name"] == colname) & (dataset["Congress Dist"] == grid[0]) & (dataset["Year Acquired"] > 1600) ].groupby("Year Acquired")["Square Footage"].sum().reset_index()
        lines.x = new_df['Year Acquired']
        lines.y = new_df['Square Footage']

# %%
col_sc = bqplot.ColorScale(scheme = "Reds")
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()

c_ax = bqplot.ColorAxis(scale = col_sc, 
                        orientation = 'vertical', 
                        side = 'right')
x_ax = bqplot.Axis(scale = x_sc)
y_ax = bqplot.Axis(scale = y_sc, 
                   orientation = 'vertical')

heat_map = bqplot.GridHeatMap(color = data,
                              scales = {'color': col_sc,
                                        'row': y_sc,
                                        'column': x_sc},
                              interactions = {'click': 'select'}, # make interactive on click of each box
                              anchor_style = {'fill':'blue'}, # to make our selection blue
                              selected_style = {'opacity': 1.0}, # make 100% opaque if box is selected
                              unselected_style = {'opacity': 0.8}) # make a little see-through if not

heat_map.observe(on_selected, 'selected')

x_scl = bqplot.LinearScale()
y_scl = bqplot.LinearScale()

x_axl = bqplot.Axis(scale = x_scl, 
                    label = 'Year')
y_axl = bqplot.Axis(scale = y_scl, 
                    orientation = 'vertical', 
                    label='Total Square Footage Acquired')


fig = bqplot.Figure(marks = [heat_map], 
                    axes = [c_ax, y_ax, x_ax])
lines = bqplot.Lines(x = lines.x, y = lines.y, scales = {'x': x_scl, 'y': y_scl})
fig_dur = bqplot.Figure(marks = [lines], axes = [x_axl, y_axl])
fig.layout.min_width = '500px' # feel free to change for your screen
fig_dur.layout.min_width = '500px'

figures = ipywidgets.HBox([fig, fig_dur])

# %%
x_axl
# Out:
# Axis(label='Year', scale=LinearScale(), side='bottom')

# %%
figures

# %% [markdown]
# ### Can you keep the x and y ranges static on the line plot?

# %% [markdown]
# #### No, I can't. the x and y ranges depend on the data scale. In the line plot, the data scale can automatically change.

# %% [markdown]
# ### Can you change the style?

# %% [markdown]
# #### yes I can. The schema(ColorScale) can be set to "blue", "red" and any other styles.

# %%
Any data transformations or rescalings you did for your plot
How you dealt with NaN's (empty entries) in your dataset
Any aesthetic choices you made (colors, layout, plot size, label size) and why, and what you'd like to experiment with if you had more time.

# %% [markdown]
# ### Any data transformations or rescalings you did for your plot

# %% [markdown]
# #### Since the building in the USA cannot be required before 1600, I set the year range between 1600 and now.

# %% [markdown]
# ### How you dealt with NaN's (empty entries) in your dataset

# %% [markdown]
# #### I replace the NaN values with 0.

# %% [markdown]
# ### Any aesthetic choices you made (colors, layout, plot size, label size) and why, and what you'd like to experiment with if you had more time.

# %% [markdown]
# #### The size of both two plot are set as 500px. The schema is set as "red". I choose the style because it is most comforable for viewers. If I had more time, I will try to link some other variables, such as "Bldg Status" to the plot.
